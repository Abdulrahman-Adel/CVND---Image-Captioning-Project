# %% [markdown]
# # Computer Vision Nanodegree
#
# ## Project: Image Captioning
#
# ---
#
# In this notebook, you will train your CNN-RNN model.
#
# You are welcome and encouraged to try out many different architectures and hyperparameters when searching for a good model.
#
# This does have the potential to make the project quite messy!  Before submitting your project, make sure that you clean up:
# - the code you write in this notebook.  The notebook should describe how to train a single CNN-RNN architecture, corresponding to your final choice of hyperparameters.  You should structure the notebook so that the reviewer can replicate your results by running the code in this notebook.
# - the output of the code cell in **Step 2**.  The output should show the output obtained when training the model from scratch.
#
# This notebook **will be graded**.
#
# Feel free to use the links below to navigate the notebook:
# - [Step 1](#step1): Training Setup
# - [Step 2](#step2): Train your Model
# - [Step 3](#step3): (Optional) Validate your Model

# %% [markdown]
# <a id='step1'></a>
# ## Step 1: Training Setup
#
# In this step of the notebook, you will customize the training of your CNN-RNN model by specifying hyperparameters and setting other options that are important to the training procedure.  The values you set now will be used when training your model in **Step 2** below.
#
# You should only amend blocks of code that are preceded by a `TODO` statement.  **Any code blocks that are not preceded by a `TODO` statement should not be modified**.
#
# ### Task #1
#
# Begin by setting the following variables:
# - `batch_size` - the batch size of each training batch.  It is the number of image-caption pairs used to amend the model weights in each training step.
# - `vocab_threshold` - the minimum word count threshold.  Note that a larger threshold will result in a smaller vocabulary, whereas a smaller threshold will include rarer words and result in a larger vocabulary.
# - `vocab_from_file` - a Boolean that decides whether to load the vocabulary from file.
# - `embed_size` - the dimensionality of the image and word embeddings.
# - `hidden_size` - the number of features in the hidden state of the RNN decoder.
# - `num_epochs` - the number of epochs to train the model.  We recommend that you set `num_epochs=3`, but feel free to increase or decrease this number as you wish.  [This paper](https://arxiv.org/pdf/1502.03044.pdf) trained a captioning model on a single state-of-the-art GPU for 3 days, but you'll soon see that you can get reasonable results in a matter of a few hours!  (_But of course, if you want your model to compete with current research, you will have to train for much longer._)
# - `save_every` - determines how often to save the model weights.  We recommend that you set `save_every=1`, to save the model weights after each epoch.  This way, after the `i`th epoch, the encoder and decoder weights will be saved in the `models/` folder as `encoder-i.pkl` and `decoder-i.pkl`, respectively.
# - `print_every` - determines how often to print the batch loss to the Jupyter notebook while training.  Note that you **will not** observe a monotonic decrease in the loss function while training - this is perfectly fine and completely expected!  You are encouraged to keep this at its default value of `100` to avoid clogging the notebook, but feel free to change it.
# - `log_file` - the name of the text file containing - for every step - how the loss and perplexity evolved during training.
#
# If you're not sure where to begin to set some of the values above, you can peruse [this paper](https://arxiv.org/pdf/1502.03044.pdf) and [this paper](https://arxiv.org/pdf/1411.4555.pdf) for useful guidance!  **To avoid spending too long on this notebook**, you are encouraged to consult these suggested research papers to obtain a strong initial guess for which hyperparameters are likely to work best.  Then, train a single model, and proceed to the next notebook (**3_Inference.ipynb**).  If you are unhappy with your performance, you can return to this notebook to tweak the hyperparameters (and/or the architecture in **model.py**) and re-train your model.
#
# ### Question 1
#
# **Question:** Describe your CNN-RNN architecture in detail.  With this architecture in mind, how did you select the values of the variables in Task 1?  If you consulted a research paper detailing a successful implementation of an image captioning model, please provide the reference.
#
# **Answer:** I didn't change the default CNN architecture as it worded fine. for the Decoder first i used an embedding layers for captions and concatenate it with the features and inputed it to an lstm layer and finaly a linear layer.
# I selected the values in task 1 as i interpreted and understood from this [this paper](https://arxiv.org/pdf/1502.03044.pdf)
#
#
# ### (Optional) Task #2
#
# Note that we have provided a recommended image transform `transform_train` for pre-processing the training images, but you are welcome (and encouraged!) to modify it as you wish.  When modifying this transform, keep in mind that:
# - the images in the dataset have varying heights and widths, and
# - if using a pre-trained model, you must perform the corresponding appropriate normalization.
#
# ### Question 2
#
# **Question:** How did you select the transform in `transform_train`?  If you left the transform at its provided value, why do you think that it is a good choice for your CNN architecture?
#
# **Answer:** I didn't change the default transform. I think it's sufficient.
# By sufficient I mean it did all nessesary operations from first resizing the input images to a fixed size then converting them to a tensor  and normalizing them with (mean, std) and also added some data augmentation techniques ( RandomCrop , RandomHorizontalFlip)
# I think adding a RandomVerticalFlip wouldn't hurt the perfomance of the model. but may improve it.
#
# ### Task #3
#
# Next, you will specify a Python list containing the learnable parameters of the model.  For instance, if you decide to make all weights in the decoder trainable, but only want to train the weights in the embedding layer of the encoder, then you should set `params` to something like:
# ```
# params = list(decoder.parameters()) + list(encoder.embed.parameters())
# ```
#
# ### Question 3
#
# **Question:** How did you select the trainable parameters of your architecture?  Why do you think this is a good choice?
#
# **Answer:** Resnet50 is pretrained so for the CNN architecture only the linear layer is trained. as for the RNN architecture the parameters of all layers is trained.
#
# ### Task #4
#
# Finally, you will select an [optimizer](http://pytorch.org/docs/master/optim.html#torch.optim.Optimizer).
#
# ### Question 4
#
# **Question:** How did you select the optimizer used to train your model?
#
# **Answer:** I started out with Adam optimizer with a learning rate of 0.001 and it worked fine so i didn't change it.

# %%
import torch
import torch.nn as nn
from torchvision import transforms
import sys
sys.path.append('/opt/cocoapi/PythonAPI')
from pycocotools.coco import COCO
from data_loader import get_loader
from model import EncoderCNN, DecoderRNN
import math
import nltk
nltk.download('punkt')


## TODO #1: Select appropriate values for the Python variables below.
batch_size =  32        # batch size
vocab_threshold = 4        # minimum word count threshold
vocab_from_file = True    # if True, load existing vocab file
embed_size = 512           # dimensionality of image and word embeddings
hidden_size = 256          # number of features in hidden state of the RNN decoder
num_epochs = 3             # number of training epochs
save_every = 1             # determines frequency of saving model weights
print_every = 100          # determines window for printing average loss
log_file = 'training_log.txt'       # name of file with saved training loss and perplexity

# (Optional) TODO #2: Amend the image transform below.
transform_train = transforms.Compose([ 
    transforms.Resize(256),                          # smaller edge of image resized to 256
    transforms.RandomCrop(224),                      # get 224x224 crop from random location
    transforms.RandomHorizontalFlip(),               # horizontally flip image with probability=0.5
    transforms.ToTensor(),                           # convert the PIL Image to a tensor
    transforms.Normalize((0.485, 0.456, 0.406),      # normalize image for pre-trained model
                         (0.229, 0.224, 0.225))])

# Build data loader.
data_loader = get_loader(transform=transform_train,
                         mode='train',
                         batch_size=batch_size,
                         vocab_threshold=vocab_threshold,
                         vocab_from_file=vocab_from_file)

# The size of the vocabulary.
vocab_size = len(data_loader.dataset.vocab)

# Initialize the encoder and decoder. 
encoder = EncoderCNN(embed_size)
decoder = DecoderRNN(embed_size, hidden_size, vocab_size)

# Move models to GPU if CUDA is available. 
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
encoder.to(device)
decoder.to(device)

# Define the loss function. 
criterion = nn.CrossEntropyLoss().cuda() if torch.cuda.is_available() else nn.CrossEntropyLoss()

# TODO #3: Specify the learnable parameters of the model.
params = list(decoder.parameters()) + list(filter(lambda p: p.requires_grad, encoder.parameters()))

# TODO #4: Define the optimizer.
optimizer = torch.optim.Adam(params, lr = 0.001)

# Set the total number of training steps per epoch.
total_step = math.ceil(len(data_loader.dataset.caption_lengths) / data_loader.batch_sampler.batch_size)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# Vocabulary successfully loaded from vocab.pkl file!
# loading annotations into memory...
# Done (t=1.16s)
# creating index...
#   0%|          | 806/414113 [00:00<01:48, 3801.24it/s]
# index created!
# Obtaining caption lengths...
# 100%|██████████| 414113/414113 [01:29<00:00, 4632.56it/s]
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.torch/models/resnet50-19c8e357.pth
# 100%|██████████| 102502400/102502400 [00:02<00:00, 43653195.89it/s]

# %% [markdown]
# <a id='step2'></a>
# ## Step 2: Train your Model
#
# Once you have executed the code cell in **Step 1**, the training procedure below should run without issue.
#
# It is completely fine to leave the code cell below as-is without modifications to train your model.  However, if you would like to modify the code used to train the model below, you must ensure that your changes are easily parsed by your reviewer.  In other words, make sure to provide appropriate comments to describe how your code works!
#
# You may find it useful to load saved weights to resume training.  In that case, note the names of the files containing the encoder and decoder weights that you'd like to load (`encoder_file` and `decoder_file`).  Then you can load the weights by using the lines below:
#
# ```python
# # Load pre-trained weights before resuming training.
# encoder.load_state_dict(torch.load(os.path.join('./models', encoder_file)))
# decoder.load_state_dict(torch.load(os.path.join('./models', decoder_file)))
# ```
#
# While trying out parameters, make sure to take extensive notes and record the settings that you used in your various training runs.  In particular, you don't want to encounter a situation where you've trained a model for several hours but can't remember what settings you used :).
#
# ### A Note on Tuning Hyperparameters
#
# To figure out how well your model is doing, you can look at how the training loss and perplexity evolve during training - and for the purposes of this project, you are encouraged to amend the hyperparameters based on this information.
#
# However, this will not tell you if your model is overfitting to the training data, and, unfortunately, overfitting is a problem that is commonly encountered when training image captioning models.
#
# For this project, you need not worry about overfitting. **This project does not have strict requirements regarding the performance of your model**, and you just need to demonstrate that your model has learned **_something_** when you generate captions on the test data.  For now, we strongly encourage you to train your model for the suggested 3 epochs without worrying about performance; then, you should immediately transition to the next notebook in the sequence (**3_Inference.ipynb**) to see how your model performs on the test data.  If your model needs to be changed, you can come back to this notebook, amend hyperparameters (if necessary), and re-train the model.
#
# That said, if you would like to go above and beyond in this project, you can read about some approaches to minimizing overfitting in section 4.3.1 of [this paper](http://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=7505636).  In the next (optional) step of this notebook, we provide some guidance for assessing the performance on the validation dataset.

# %%
import torch.utils.data as data
import numpy as np
import os
import requests
import time
from workspace_utils import keep_awake

# Open the training log file.
f = open(log_file, 'w')

old_time = time.time()
response = requests.request("GET", 
                            "http://metadata.google.internal/computeMetadata/v1/instance/attributes/keep_alive_token", 
                            headers={"Metadata-Flavor":"Google"})

for epoch in keep_awake(range(1, num_epochs+1)):
    
    for i_step in range(1, total_step+1):
        
        if time.time() - old_time > 60:
            old_time = time.time()
            requests.request("POST", 
                             "https://nebula.udacity.com/api/v1/remote/keep-alive", 
                             headers={'Authorization': "STAR " + response.text})
        
        # Randomly sample a caption length, and sample indices with that length.
        indices = data_loader.dataset.get_train_indices()
        # Create and assign a batch sampler to retrieve a batch with the sampled indices.
        new_sampler = data.sampler.SubsetRandomSampler(indices=indices)
        data_loader.batch_sampler.sampler = new_sampler
        
        # Obtain the batch.
        images, captions = next(iter(data_loader))

        # Move batch of images and captions to GPU if CUDA is available.
        images = images.to(device)
        captions = captions.to(device)
        
        # Zero the gradients.
        decoder.zero_grad()
        encoder.zero_grad()
        
        # Pass the inputs through the CNN-RNN model.
        features = encoder(images)
        outputs = decoder(features, captions)
        
        # Calculate the batch loss.
        loss = criterion(outputs.view(-1, vocab_size), captions.view(-1))
        
        # Backward pass.
        loss.backward()
        
        # Update the parameters in the optimizer.
        optimizer.step()
            
        # Get training statistics.
        stats = 'Epoch [%d/%d], Step [%d/%d], Loss: %.4f, Perplexity: %5.4f' % (epoch, num_epochs, i_step, total_step, loss.item(), np.exp(loss.item()))
        
        # Print training statistics (on same line).
        print('\r' + stats, end="")
        sys.stdout.flush()
        
        # Print training statistics to file.
        f.write(stats + '\n')
        f.flush()
        
        # Print training statistics (on different line).
        if i_step % print_every == 0:
            print('\r' + stats)
            
    # Save the weights.
    if epoch % save_every == 0:
        torch.save(decoder.state_dict(), os.path.join('./models', 'decoder-%d.pkl' % epoch))
        torch.save(encoder.state_dict(), os.path.join('./models', 'encoder-%d.pkl' % epoch))

# Close the training log file.
f.close()
# Out:
# Epoch [1/3], Step [100/12942], Loss: 4.3740, Perplexity: 79.35907
# Epoch [1/3], Step [200/12942], Loss: 3.5547, Perplexity: 34.97819
# Epoch [1/3], Step [300/12942], Loss: 3.8467, Perplexity: 46.83911
# Epoch [1/3], Step [400/12942], Loss: 3.3685, Perplexity: 29.03579
# Epoch [1/3], Step [500/12942], Loss: 3.5502, Perplexity: 34.82139
# Epoch [1/3], Step [600/12942], Loss: 4.2898, Perplexity: 72.9549
# Epoch [1/3], Step [700/12942], Loss: 3.1862, Perplexity: 24.1957
# Epoch [1/3], Step [800/12942], Loss: 3.0080, Perplexity: 20.2466
# Epoch [1/3], Step [900/12942], Loss: 3.3420, Perplexity: 28.27444
# Epoch [1/3], Step [1000/12942], Loss: 2.9742, Perplexity: 19.5734
# Epoch [1/3], Step [1100/12942], Loss: 3.1285, Perplexity: 22.8404
# Epoch [1/3], Step [1200/12942], Loss: 2.9651, Perplexity: 19.3966
# Epoch [1/3], Step [1300/12942], Loss: 3.0310, Perplexity: 20.7183
# Epoch [1/3], Step [1400/12942], Loss: 3.1967, Perplexity: 24.4505
# Epoch [1/3], Step [1500/12942], Loss: 3.5447, Perplexity: 34.6303
# Epoch [1/3], Step [1600/12942], Loss: 2.7460, Perplexity: 15.5808
# Epoch [1/3], Step [1700/12942], Loss: 2.8543, Perplexity: 17.3627
# Epoch [1/3], Step [1800/12942], Loss: 2.8344, Perplexity: 17.0196
# Epoch [1/3], Step [1900/12942], Loss: 2.8530, Perplexity: 17.3397
# Epoch [1/3], Step [2000/12942], Loss: 3.1552, Perplexity: 23.4587
# Epoch [1/3], Step [2100/12942], Loss: 2.6896, Perplexity: 14.7259
# Epoch [1/3], Step [2200/12942], Loss: 2.6289, Perplexity: 13.8589
# Epoch [1/3], Step [2300/12942], Loss: 2.5875, Perplexity: 13.2968
# Epoch [1/3], Step [2400/12942], Loss: 3.1538, Perplexity: 23.4245
# Epoch [1/3], Step [2500/12942], Loss: 2.5237, Perplexity: 12.4740
# Epoch [1/3], Step [2600/12942], Loss: 2.9584, Perplexity: 19.2666
# Epoch [1/3], Step [2700/12942], Loss: 2.9098, Perplexity: 18.3529
# Epoch [1/3], Step [2800/12942], Loss: 2.6118, Perplexity: 13.6239
# Epoch [1/3], Step [2900/12942], Loss: 2.6810, Perplexity: 14.5998
# Epoch [1/3], Step [3000/12942], Loss: 2.7670, Perplexity: 15.9112
# Epoch [1/3], Step [3100/12942], Loss: 2.7891, Perplexity: 16.2671
# Epoch [1/3], Step [3200/12942], Loss: 2.9481, Perplexity: 19.0706
# Epoch [1/3], Step [3300/12942], Loss: 2.7296, Perplexity: 15.3261
# Epoch [1/3], Step [3400/12942], Loss: 2.6386, Perplexity: 13.9931
# Epoch [1/3], Step [3500/12942], Loss: 2.7980, Perplexity: 16.4117
# Epoch [1/3], Step [3600/12942], Loss: 2.4286, Perplexity: 11.3435
# Epoch [1/3], Step [3700/12942], Loss: 2.7570, Perplexity: 15.7533
# Epoch [1/3], Step [3800/12942], Loss: 2.8134, Perplexity: 16.6662
# Epoch [1/3], Step [3900/12942], Loss: 2.3452, Perplexity: 10.4349
# Epoch [1/3], Step [4000/12942], Loss: 2.9375, Perplexity: 18.8687
# Epoch [1/3], Step [4100/12942], Loss: 2.8246, Perplexity: 16.8548
# Epoch [1/3], Step [4200/12942], Loss: 2.5161, Perplexity: 12.3806
# Epoch [1/3], Step [4300/12942], Loss: 3.1625, Perplexity: 23.6292
# Epoch [1/3], Step [4400/12942], Loss: 2.5464, Perplexity: 12.7606
# Epoch [1/3], Step [4500/12942], Loss: 2.6205, Perplexity: 13.7427
# Epoch [1/3], Step [4600/12942], Loss: 2.7182, Perplexity: 15.1524
# Epoch [1/3], Step [4700/12942], Loss: 2.7271, Perplexity: 15.2881
# Epoch [1/3], Step [4800/12942], Loss: 2.5707, Perplexity: 13.0754
# Epoch [1/3], Step [4900/12942], Loss: 3.1329, Perplexity: 22.9400
# Epoch [1/3], Step [5000/12942], Loss: 2.4433, Perplexity: 11.5110
# Epoch [1/3], Step [5100/12942], Loss: 2.7318, Perplexity: 15.3609
# Epoch [1/3], Step [5200/12942], Loss: 2.1983, Perplexity: 9.00970
# Epoch [1/3], Step [5300/12942], Loss: 2.8620, Perplexity: 17.4974
# Epoch [1/3], Step [5400/12942], Loss: 2.1567, Perplexity: 8.64291
# Epoch [1/3], Step [5500/12942], Loss: 2.3234, Perplexity: 10.2105
# Epoch [1/3], Step [5600/12942], Loss: 2.5791, Perplexity: 13.1853
# Epoch [1/3], Step [5700/12942], Loss: 2.3836, Perplexity: 10.8443
# Epoch [1/3], Step [5800/12942], Loss: 2.9745, Perplexity: 19.5794
# Epoch [1/3], Step [5900/12942], Loss: 2.7020, Perplexity: 14.9091
# Epoch [1/3], Step [6000/12942], Loss: 2.6304, Perplexity: 13.8793
# Epoch [1/3], Step [6100/12942], Loss: 2.3188, Perplexity: 10.1630
# Epoch [1/3], Step [6200/12942], Loss: 2.2981, Perplexity: 9.95575
# Epoch [1/3], Step [6300/12942], Loss: 2.6421, Perplexity: 14.0431
# Epoch [1/3], Step [6400/12942], Loss: 2.6340, Perplexity: 13.9299
# Epoch [1/3], Step [6500/12942], Loss: 2.2909, Perplexity: 9.88343
# Epoch [1/3], Step [6600/12942], Loss: 2.3444, Perplexity: 10.4267
# Epoch [1/3], Step [6700/12942], Loss: 2.4836, Perplexity: 11.9839
# Epoch [1/3], Step [6800/12942], Loss: 3.2857, Perplexity: 26.7290
# Epoch [1/3], Step [6900/12942], Loss: 2.5357, Perplexity: 12.6251
# Epoch [1/3], Step [7000/12942], Loss: 2.5046, Perplexity: 12.2389
# Epoch [1/3], Step [7100/12942], Loss: 2.3948, Perplexity: 10.9658
# Epoch [1/3], Step [7200/12942], Loss: 2.5879, Perplexity: 13.3017
# Epoch [1/3], Step [7300/12942], Loss: 2.3698, Perplexity: 10.6955
# Epoch [1/3], Step [7400/12942], Loss: 2.2168, Perplexity: 9.17821
# Epoch [1/3], Step [7500/12942], Loss: 2.4374, Perplexity: 11.4433
# Epoch [1/3], Step [7600/12942], Loss: 2.5320, Perplexity: 12.5782
# Epoch [1/3], Step [7700/12942], Loss: 2.7939, Perplexity: 16.3443
# Epoch [1/3], Step [7800/12942], Loss: 2.5095, Perplexity: 12.2988
# Epoch [1/3], Step [7900/12942], Loss: 2.4839, Perplexity: 11.9885
# Epoch [1/3], Step [8000/12942], Loss: 2.3379, Perplexity: 10.3593
# Epoch [1/3], Step [8100/12942], Loss: 2.1305, Perplexity: 8.419312
# Epoch [1/3], Step [8200/12942], Loss: 2.3472, Perplexity: 10.4558
# Epoch [1/3], Step [8300/12942], Loss: 2.3505, Perplexity: 10.4905
# Epoch [1/3], Step [8400/12942], Loss: 2.1645, Perplexity: 8.71028
# Epoch [1/3], Step [8500/12942], Loss: 2.4453, Perplexity: 11.5334
# Epoch [1/3], Step [8600/12942], Loss: 2.2115, Perplexity: 9.12963
# Epoch [1/3], Step [8700/12942], Loss: 2.4920, Perplexity: 12.0849
# Epoch [1/3], Step [8800/12942], Loss: 2.1759, Perplexity: 8.80978
# Epoch [1/3], Step [8900/12942], Loss: 3.0211, Perplexity: 20.5138
# Epoch [1/3], Step [9000/12942], Loss: 2.0532, Perplexity: 7.79250
# Epoch [1/3], Step [9100/12942], Loss: 2.7356, Perplexity: 15.4184
# Epoch [1/3], Step [9200/12942], Loss: 2.2332, Perplexity: 9.32994
# Epoch [1/3], Step [9300/12942], Loss: 2.3417, Perplexity: 10.3989
# Epoch [1/3], Step [9400/12942], Loss: 2.5353, Perplexity: 12.6198
# Epoch [1/3], Step [9500/12942], Loss: 2.3857, Perplexity: 10.8663
# Epoch [1/3], Step [9600/12942], Loss: 2.3197, Perplexity: 10.1729
# Epoch [1/3], Step [9700/12942], Loss: 2.3189, Perplexity: 10.1649
# Epoch [1/3], Step [9800/12942], Loss: 2.6134, Perplexity: 13.6460
# Epoch [1/3], Step [9900/12942], Loss: 2.1653, Perplexity: 8.71733
# Epoch [1/3], Step [10000/12942], Loss: 2.3004, Perplexity: 9.9781
# Epoch [1/3], Step [10100/12942], Loss: 2.1516, Perplexity: 8.59843
# Epoch [1/3], Step [10200/12942], Loss: 2.4135, Perplexity: 11.1733
# Epoch [1/3], Step [10300/12942], Loss: 2.5212, Perplexity: 12.4441
# Epoch [1/3], Step [10400/12942], Loss: 2.2771, Perplexity: 9.74848
# Epoch [1/3], Step [10500/12942], Loss: 2.3439, Perplexity: 10.4216
# Epoch [1/3], Step [10600/12942], Loss: 2.2192, Perplexity: 9.19974
# Epoch [1/3], Step [10700/12942], Loss: 2.4877, Perplexity: 12.0341
# Epoch [1/3], Step [10800/12942], Loss: 2.3185, Perplexity: 10.1609
# Epoch [1/3], Step [10900/12942], Loss: 2.2078, Perplexity: 9.09597
# Epoch [1/3], Step [11000/12942], Loss: 2.3342, Perplexity: 10.3217
# Epoch [1/3], Step [11100/12942], Loss: 2.4787, Perplexity: 11.9258
# Epoch [1/3], Step [11200/12942], Loss: 2.0468, Perplexity: 7.74297
# Epoch [1/3], Step [11300/12942], Loss: 2.2095, Perplexity: 9.11072
# Epoch [1/3], Step [11400/12942], Loss: 2.1465, Perplexity: 8.55492
# Epoch [1/3], Step [11500/12942], Loss: 3.5721, Perplexity: 35.5896
# Epoch [1/3], Step [11600/12942], Loss: 2.5557, Perplexity: 12.8804
# Epoch [1/3], Step [11700/12942], Loss: 2.2218, Perplexity: 9.22392
# Epoch [1/3], Step [11800/12942], Loss: 2.1101, Perplexity: 8.24900
# Epoch [1/3], Step [11900/12942], Loss: 2.1626, Perplexity: 8.69366
# Epoch [1/3], Step [12000/12942], Loss: 2.1521, Perplexity: 8.60284
# Epoch [1/3], Step [12100/12942], Loss: 3.1340, Perplexity: 22.9656
# Epoch [1/3], Step [12200/12942], Loss: 2.0635, Perplexity: 7.87326
# Epoch [1/3], Step [12300/12942], Loss: 2.3237, Perplexity: 10.2130
# Epoch [1/3], Step [12400/12942], Loss: 2.3040, Perplexity: 10.0138
# Epoch [1/3], Step [12500/12942], Loss: 2.2293, Perplexity: 9.29378
# Epoch [1/3], Step [12600/12942], Loss: 2.4243, Perplexity: 11.2939
# Epoch [1/3], Step [12700/12942], Loss: 2.2122, Perplexity: 9.13615
# Epoch [1/3], Step [12800/12942], Loss: 2.5711, Perplexity: 13.0796
# Epoch [1/3], Step [12900/12942], Loss: 2.2928, Perplexity: 9.90285
# Epoch [2/3], Step [100/12942], Loss: 2.3189, Perplexity: 10.164506
# Epoch [2/3], Step [200/12942], Loss: 2.2670, Perplexity: 9.65038
# Epoch [2/3], Step [300/12942], Loss: 2.5118, Perplexity: 12.3277
# Epoch [2/3], Step [400/12942], Loss: 2.1745, Perplexity: 8.79819
# Epoch [2/3], Step [500/12942], Loss: 2.0131, Perplexity: 7.48682
# Epoch [2/3], Step [600/12942], Loss: 2.1703, Perplexity: 8.76120
# Epoch [2/3], Step [700/12942], Loss: 2.0904, Perplexity: 8.08810
# Epoch [2/3], Step [800/12942], Loss: 2.2984, Perplexity: 9.95812
# Epoch [2/3], Step [900/12942], Loss: 2.2258, Perplexity: 9.26057
# Epoch [2/3], Step [1000/12942], Loss: 2.2856, Perplexity: 9.8318
# Epoch [2/3], Step [1100/12942], Loss: 2.0313, Perplexity: 7.62404
# Epoch [2/3], Step [1200/12942], Loss: 2.5771, Perplexity: 13.1590
# Epoch [2/3], Step [1300/12942], Loss: 2.2333, Perplexity: 9.33088
# Epoch [2/3], Step [1400/12942], Loss: 2.1634, Perplexity: 8.70093
# Epoch [2/3], Step [1500/12942], Loss: 2.3032, Perplexity: 10.0064
# Epoch [2/3], Step [1600/12942], Loss: 2.1172, Perplexity: 8.30764
# Epoch [2/3], Step [1700/12942], Loss: 3.0245, Perplexity: 20.5839
# Epoch [2/3], Step [1800/12942], Loss: 2.1841, Perplexity: 8.88239
# Epoch [2/3], Step [1900/12942], Loss: 2.6318, Perplexity: 13.8986
# Epoch [2/3], Step [2000/12942], Loss: 2.4348, Perplexity: 11.4136
# Epoch [2/3], Step [2100/12942], Loss: 2.3174, Perplexity: 10.1491
# Epoch [2/3], Step [2200/12942], Loss: 2.1901, Perplexity: 8.93649
# Epoch [2/3], Step [2300/12942], Loss: 2.2302, Perplexity: 9.30187
# Epoch [2/3], Step [2400/12942], Loss: 2.1488, Perplexity: 8.57484
# Epoch [2/3], Step [2500/12942], Loss: 2.1463, Perplexity: 8.55301
# Epoch [2/3], Step [2600/12942], Loss: 2.0640, Perplexity: 7.87736
# Epoch [2/3], Step [2700/12942], Loss: 2.4517, Perplexity: 11.6081
# Epoch [2/3], Step [2800/12942], Loss: 2.7592, Perplexity: 15.7869
# Epoch [2/3], Step [2900/12942], Loss: 2.4058, Perplexity: 11.0869
# Epoch [2/3], Step [3000/12942], Loss: 2.4859, Perplexity: 12.0125
# Epoch [2/3], Step [3100/12942], Loss: 2.1063, Perplexity: 8.21794
# Epoch [2/3], Step [3200/12942], Loss: 2.2539, Perplexity: 9.52488
# Epoch [2/3], Step [3300/12942], Loss: 2.2837, Perplexity: 9.81284
# Epoch [2/3], Step [3400/12942], Loss: 2.1253, Perplexity: 8.37542
# Epoch [2/3], Step [3500/12942], Loss: 2.0723, Perplexity: 7.94276
# Epoch [2/3], Step [3600/12942], Loss: 2.1561, Perplexity: 8.63740
# Epoch [2/3], Step [3700/12942], Loss: 2.2393, Perplexity: 9.38707
# Epoch [2/3], Step [3800/12942], Loss: 2.0916, Perplexity: 8.09764
# Epoch [2/3], Step [3900/12942], Loss: 2.1929, Perplexity: 8.96071
# Epoch [2/3], Step [4000/12942], Loss: 2.0003, Perplexity: 7.39097
# Epoch [2/3], Step [4100/12942], Loss: 2.0864, Perplexity: 8.05591
# Epoch [2/3], Step [4200/12942], Loss: 2.4959, Perplexity: 12.1325
# Epoch [2/3], Step [4300/12942], Loss: 2.5427, Perplexity: 12.7135
# Epoch [2/3], Step [4400/12942], Loss: 2.3006, Perplexity: 9.98021
# Epoch [2/3], Step [4500/12942], Loss: 2.3994, Perplexity: 11.0169
# Epoch [2/3], Step [4600/12942], Loss: 2.5161, Perplexity: 12.3796
# Epoch [2/3], Step [4700/12942], Loss: 2.5407, Perplexity: 12.6884
# Epoch [2/3], Step [4800/12942], Loss: 2.2792, Perplexity: 9.76862
# Epoch [2/3], Step [4900/12942], Loss: 2.0582, Perplexity: 7.83178
# Epoch [2/3], Step [5000/12942], Loss: 2.1199, Perplexity: 8.33028
# Epoch [2/3], Step [5100/12942], Loss: 2.0837, Perplexity: 8.03450
# Epoch [2/3], Step [5200/12942], Loss: 2.0500, Perplexity: 7.76771
# Epoch [2/3], Step [5300/12942], Loss: 2.2703, Perplexity: 9.68200
# Epoch [2/3], Step [5400/12942], Loss: 2.4893, Perplexity: 12.0533
# Epoch [2/3], Step [5500/12942], Loss: 1.9417, Perplexity: 6.97032
# Epoch [2/3], Step [5600/12942], Loss: 2.2725, Perplexity: 9.70388
# Epoch [2/3], Step [5700/12942], Loss: 2.1641, Perplexity: 8.70648
# Epoch [2/3], Step [5800/12942], Loss: 2.2673, Perplexity: 9.65304
# Epoch [2/3], Step [5900/12942], Loss: 2.0737, Perplexity: 7.95416
# Epoch [2/3], Step [6000/12942], Loss: 2.2532, Perplexity: 9.51789
# Epoch [2/3], Step [6100/12942], Loss: 2.4052, Perplexity: 11.0805
# Epoch [2/3], Step [6200/12942], Loss: 2.1640, Perplexity: 8.70632
# Epoch [2/3], Step [6300/12942], Loss: 2.1249, Perplexity: 8.37240
# Epoch [2/3], Step [6400/12942], Loss: 2.2517, Perplexity: 9.50360
# Epoch [2/3], Step [6500/12942], Loss: 2.1215, Perplexity: 8.34379
# Epoch [2/3], Step [6600/12942], Loss: 2.4880, Perplexity: 12.0377
# Epoch [2/3], Step [6700/12942], Loss: 2.2978, Perplexity: 9.95230
# Epoch [2/3], Step [6800/12942], Loss: 2.0142, Perplexity: 7.49480
# Epoch [2/3], Step [6900/12942], Loss: 2.1471, Perplexity: 8.56033
# Epoch [2/3], Step [7000/12942], Loss: 2.3520, Perplexity: 10.5066
# Epoch [2/3], Step [7100/12942], Loss: 2.3552, Perplexity: 10.5402
# Epoch [2/3], Step [7200/12942], Loss: 2.5920, Perplexity: 13.3559
# Epoch [2/3], Step [7300/12942], Loss: 2.3486, Perplexity: 10.4711
# Epoch [2/3], Step [7400/12942], Loss: 2.2367, Perplexity: 9.36217
# Epoch [2/3], Step [7500/12942], Loss: 2.6818, Perplexity: 14.6110
# Epoch [2/3], Step [7600/12942], Loss: 2.1390, Perplexity: 8.49113
# Epoch [2/3], Step [7700/12942], Loss: 2.1346, Perplexity: 8.45370
# Epoch [2/3], Step [7800/12942], Loss: 2.0647, Perplexity: 7.88322
# Epoch [2/3], Step [7900/12942], Loss: 2.2484, Perplexity: 9.47282
# Epoch [2/3], Step [8000/12942], Loss: 2.0715, Perplexity: 7.93709
# Epoch [2/3], Step [8100/12942], Loss: 2.3413, Perplexity: 10.3947
# Epoch [2/3], Step [8200/12942], Loss: 2.2576, Perplexity: 9.56014
# Epoch [2/3], Step [8300/12942], Loss: 2.0167, Perplexity: 7.51328
# Epoch [2/3], Step [8400/12942], Loss: 1.8922, Perplexity: 6.63378
# Epoch [2/3], Step [8500/12942], Loss: 2.2663, Perplexity: 9.64325
# Epoch [2/3], Step [8600/12942], Loss: 2.2434, Perplexity: 9.42574
# Epoch [2/3], Step [8700/12942], Loss: 2.0293, Perplexity: 7.60895
# Epoch [2/3], Step [8800/12942], Loss: 2.9076, Perplexity: 18.3127
# Epoch [2/3], Step [8900/12942], Loss: 1.8423, Perplexity: 6.31124
# Epoch [2/3], Step [9000/12942], Loss: 2.4231, Perplexity: 11.2813
# Epoch [2/3], Step [9100/12942], Loss: 1.8646, Perplexity: 6.45320
# Epoch [2/3], Step [9200/12942], Loss: 2.2682, Perplexity: 9.66200
# Epoch [2/3], Step [9300/12942], Loss: 2.3636, Perplexity: 10.6293
# Epoch [2/3], Step [9400/12942], Loss: 2.0293, Perplexity: 7.60919
# Epoch [2/3], Step [9500/12942], Loss: 2.0975, Perplexity: 8.14581
# Epoch [2/3], Step [9600/12942], Loss: 2.1591, Perplexity: 8.66379
# Epoch [2/3], Step [9700/12942], Loss: 2.3221, Perplexity: 10.1971
# Epoch [2/3], Step [9800/12942], Loss: 2.0467, Perplexity: 7.74216
# Epoch [2/3], Step [9900/12942], Loss: 2.1517, Perplexity: 8.59984
# Epoch [2/3], Step [10000/12942], Loss: 2.2048, Perplexity: 9.0680
# Epoch [2/3], Step [10100/12942], Loss: 2.2340, Perplexity: 9.33752
# Epoch [2/3], Step [10200/12942], Loss: 2.3065, Perplexity: 10.0392
# Epoch [2/3], Step [10300/12942], Loss: 1.7709, Perplexity: 5.87648
# Epoch [2/3], Step [10400/12942], Loss: 1.9333, Perplexity: 6.91198
# Epoch [2/3], Step [10500/12942], Loss: 2.1007, Perplexity: 8.17223
# Epoch [2/3], Step [10600/12942], Loss: 2.1061, Perplexity: 8.21639
# Epoch [2/3], Step [10700/12942], Loss: 2.0532, Perplexity: 7.79295
# Epoch [2/3], Step [10800/12942], Loss: 2.1336, Perplexity: 8.44523
# Epoch [2/3], Step [10900/12942], Loss: 2.5705, Perplexity: 13.0723
# Epoch [2/3], Step [11000/12942], Loss: 2.3855, Perplexity: 10.8642
# Epoch [2/3], Step [11100/12942], Loss: 1.9089, Perplexity: 6.74581
# Epoch [2/3], Step [11200/12942], Loss: 2.0718, Perplexity: 7.93916
# Epoch [2/3], Step [11300/12942], Loss: 2.4626, Perplexity: 11.7350
# Epoch [2/3], Step [11400/12942], Loss: 2.2814, Perplexity: 9.79055
# Epoch [2/3], Step [11500/12942], Loss: 2.7383, Perplexity: 15.4614
# Epoch [2/3], Step [11600/12942], Loss: 2.4501, Perplexity: 11.5898
# Epoch [2/3], Step [11700/12942], Loss: 3.1238, Perplexity: 22.7325
# Epoch [2/3], Step [11800/12942], Loss: 1.9936, Perplexity: 7.34175
# Epoch [2/3], Step [11900/12942], Loss: 2.1100, Perplexity: 8.24814
# Epoch [2/3], Step [12000/12942], Loss: 1.9259, Perplexity: 6.86152
# Epoch [2/3], Step [12100/12942], Loss: 2.0530, Perplexity: 7.79158
# Epoch [2/3], Step [12200/12942], Loss: 2.2021, Perplexity: 9.04360
# Epoch [2/3], Step [12300/12942], Loss: 2.3607, Perplexity: 10.5979
# Epoch [2/3], Step [12400/12942], Loss: 2.0421, Perplexity: 7.70707
# Epoch [2/3], Step [12500/12942], Loss: 2.1940, Perplexity: 8.97073
# Epoch [2/3], Step [12600/12942], Loss: 2.1341, Perplexity: 8.44941
# Epoch [2/3], Step [12700/12942], Loss: 2.0849, Perplexity: 8.043783
# Epoch [2/3], Step [12800/12942], Loss: 1.8792, Perplexity: 6.54813
# Epoch [2/3], Step [12900/12942], Loss: 2.0023, Perplexity: 7.40628
# Epoch [3/3], Step [100/12942], Loss: 2.3419, Perplexity: 10.401459
# Epoch [3/3], Step [200/12942], Loss: 2.1388, Perplexity: 8.48944
# Epoch [3/3], Step [300/12942], Loss: 2.6422, Perplexity: 14.0440
# Epoch [3/3], Step [400/12942], Loss: 2.1533, Perplexity: 8.61294
# Epoch [3/3], Step [500/12942], Loss: 2.3572, Perplexity: 10.5615
# Epoch [3/3], Step [600/12942], Loss: 2.0183, Perplexity: 7.52598
# Epoch [3/3], Step [700/12942], Loss: 2.4301, Perplexity: 11.3597
# Epoch [3/3], Step [800/12942], Loss: 1.9415, Perplexity: 6.96946
# Epoch [3/3], Step [900/12942], Loss: 2.1016, Perplexity: 8.17911
# Epoch [3/3], Step [1000/12942], Loss: 2.2477, Perplexity: 9.4655
# Epoch [3/3], Step [1100/12942], Loss: 2.2796, Perplexity: 9.77308
# Epoch [3/3], Step [1200/12942], Loss: 2.2902, Perplexity: 9.87695
# Epoch [3/3], Step [1300/12942], Loss: 2.1998, Perplexity: 9.023468
# Epoch [3/3], Step [1400/12942], Loss: 2.2745, Perplexity: 9.72327
# Epoch [3/3], Step [1500/12942], Loss: 2.3186, Perplexity: 10.1611
# Epoch [3/3], Step [1600/12942], Loss: 1.8326, Perplexity: 6.24993
# Epoch [3/3], Step [1700/12942], Loss: 2.2619, Perplexity: 9.60109
# Epoch [3/3], Step [1800/12942], Loss: 2.1445, Perplexity: 8.53775
# Epoch [3/3], Step [1900/12942], Loss: 2.3929, Perplexity: 10.9457
# Epoch [3/3], Step [2000/12942], Loss: 2.1495, Perplexity: 8.58055
# Epoch [3/3], Step [2100/12942], Loss: 1.9420, Perplexity: 6.97257
# Epoch [3/3], Step [2200/12942], Loss: 2.0340, Perplexity: 7.64484
# Epoch [3/3], Step [2300/12942], Loss: 2.0447, Perplexity: 7.72718
# Epoch [3/3], Step [2400/12942], Loss: 2.3777, Perplexity: 10.7805
# Epoch [3/3], Step [2500/12942], Loss: 1.8485, Perplexity: 6.35066
# Epoch [3/3], Step [2600/12942], Loss: 2.0535, Perplexity: 7.79526
# Epoch [3/3], Step [2700/12942], Loss: 2.3055, Perplexity: 10.0290
# Epoch [3/3], Step [2800/12942], Loss: 2.1992, Perplexity: 9.01774
# Epoch [3/3], Step [2900/12942], Loss: 2.0973, Perplexity: 8.14423
# Epoch [3/3], Step [3000/12942], Loss: 1.9671, Perplexity: 7.14962
# Epoch [3/3], Step [3100/12942], Loss: 2.3634, Perplexity: 10.6274
# Epoch [3/3], Step [3200/12942], Loss: 2.1092, Perplexity: 8.24191
# Epoch [3/3], Step [3300/12942], Loss: 1.8879, Perplexity: 6.60575
# Epoch [3/3], Step [3400/12942], Loss: 1.9040, Perplexity: 6.71277
# Epoch [3/3], Step [3500/12942], Loss: 1.7774, Perplexity: 5.91477
# Epoch [3/3], Step [3600/12942], Loss: 2.4588, Perplexity: 11.6907
# Epoch [3/3], Step [3700/12942], Loss: 2.0093, Perplexity: 7.45827
# Epoch [3/3], Step [3800/12942], Loss: 2.1526, Perplexity: 8.60721
# Epoch [3/3], Step [3900/12942], Loss: 2.0143, Perplexity: 7.49540
# Epoch [3/3], Step [4000/12942], Loss: 2.2005, Perplexity: 9.02982
# Epoch [3/3], Step [4100/12942], Loss: 2.4523, Perplexity: 11.6147
# Epoch [3/3], Step [4200/12942], Loss: 2.0490, Perplexity: 7.76041
# Epoch [3/3], Step [4300/12942], Loss: 2.5192, Perplexity: 12.4181
# Epoch [3/3], Step [4400/12942], Loss: 2.2309, Perplexity: 9.30856
# Epoch [3/3], Step [4500/12942], Loss: 2.2267, Perplexity: 9.26926
# Epoch [3/3], Step [4600/12942], Loss: 2.6073, Perplexity: 13.5626
# Epoch [3/3], Step [4700/12942], Loss: 2.0139, Perplexity: 7.49210
# Epoch [3/3], Step [4800/12942], Loss: 2.2476, Perplexity: 9.46492
# Epoch [3/3], Step [4900/12942], Loss: 1.9272, Perplexity: 6.87069
# Epoch [3/3], Step [5000/12942], Loss: 1.9499, Perplexity: 7.02791
# Epoch [3/3], Step [5100/12942], Loss: 2.2918, Perplexity: 9.89295
# Epoch [3/3], Step [5200/12942], Loss: 2.4047, Perplexity: 11.0748
# Epoch [3/3], Step [5300/12942], Loss: 2.3201, Perplexity: 10.1765
# Epoch [3/3], Step [5400/12942], Loss: 2.2098, Perplexity: 9.11360
# Epoch [3/3], Step [5500/12942], Loss: 2.3336, Perplexity: 10.3153
# Epoch [3/3], Step [5600/12942], Loss: 2.1242, Perplexity: 8.36665
# Epoch [3/3], Step [5700/12942], Loss: 2.0013, Perplexity: 7.39848
# Epoch [3/3], Step [5800/12942], Loss: 2.0625, Perplexity: 7.86589
# Epoch [3/3], Step [5900/12942], Loss: 2.2869, Perplexity: 9.84439
# Epoch [3/3], Step [6000/12942], Loss: 2.0728, Perplexity: 7.94715
# Epoch [3/3], Step [6100/12942], Loss: 2.2563, Perplexity: 9.54776
# Epoch [3/3], Step [6200/12942], Loss: 2.0334, Perplexity: 7.64029
# Epoch [3/3], Step [6300/12942], Loss: 2.2528, Perplexity: 9.51442
# Epoch [3/3], Step [6400/12942], Loss: 2.1196, Perplexity: 8.32815
# Epoch [3/3], Step [6500/12942], Loss: 1.9027, Perplexity: 6.70372
# Epoch [3/3], Step [6600/12942], Loss: 2.4769, Perplexity: 11.9039
# Epoch [3/3], Step [6700/12942], Loss: 2.5831, Perplexity: 13.2380
# Epoch [3/3], Step [6800/12942], Loss: 2.0237, Perplexity: 7.56630
# Epoch [3/3], Step [6900/12942], Loss: 2.2033, Perplexity: 9.05510
# Epoch [3/3], Step [7000/12942], Loss: 2.1642, Perplexity: 8.70758
# Epoch [3/3], Step [7100/12942], Loss: 2.3382, Perplexity: 10.3626
# Epoch [3/3], Step [7200/12942], Loss: 1.9826, Perplexity: 7.26172
# Epoch [3/3], Step [7300/12942], Loss: 1.9328, Perplexity: 6.90879
# Epoch [3/3], Step [7400/12942], Loss: 1.8679, Perplexity: 6.47478
# Epoch [3/3], Step [7500/12942], Loss: 1.9955, Perplexity: 7.35605
# Epoch [3/3], Step [7600/12942], Loss: 1.9453, Perplexity: 6.99553
# Epoch [3/3], Step [7700/12942], Loss: 2.1304, Perplexity: 8.41830
# Epoch [3/3], Step [7800/12942], Loss: 1.9656, Perplexity: 7.13906
# Epoch [3/3], Step [7900/12942], Loss: 3.1084, Perplexity: 22.3862
# Epoch [3/3], Step [8000/12942], Loss: 2.0720, Perplexity: 7.94051
# Epoch [3/3], Step [8100/12942], Loss: 2.4355, Perplexity: 11.4215
# Epoch [3/3], Step [8200/12942], Loss: 2.2314, Perplexity: 9.31290
# Epoch [3/3], Step [8300/12942], Loss: 2.5702, Perplexity: 13.0688
# Epoch [3/3], Step [8400/12942], Loss: 2.2124, Perplexity: 9.13754
# Epoch [3/3], Step [8500/12942], Loss: 1.9387, Perplexity: 6.94948
# Epoch [3/3], Step [8600/12942], Loss: 2.2847, Perplexity: 9.82272
# Epoch [3/3], Step [8700/12942], Loss: 2.0233, Perplexity: 7.56330
# Epoch [3/3], Step [8800/12942], Loss: 2.1936, Perplexity: 8.96774
# Epoch [3/3], Step [8900/12942], Loss: 1.9885, Perplexity: 7.30451
# Epoch [3/3], Step [9000/12942], Loss: 2.2247, Perplexity: 9.25088
# Epoch [3/3], Step [9100/12942], Loss: 2.2338, Perplexity: 9.33510
# Epoch [3/3], Step [9200/12942], Loss: 1.9140, Perplexity: 6.77995
# Epoch [3/3], Step [9300/12942], Loss: 2.1429, Perplexity: 8.52438
# Epoch [3/3], Step [9400/12942], Loss: 2.2111, Perplexity: 9.12592
# Epoch [3/3], Step [9500/12942], Loss: 2.1970, Perplexity: 8.99766
# Epoch [3/3], Step [9600/12942], Loss: 1.7721, Perplexity: 5.88310
# Epoch [3/3], Step [9700/12942], Loss: 2.0942, Perplexity: 8.11861
# Epoch [3/3], Step [9800/12942], Loss: 2.2217, Perplexity: 9.22318
# Epoch [3/3], Step [9900/12942], Loss: 2.5022, Perplexity: 12.2089
# Epoch [3/3], Step [10000/12942], Loss: 2.3275, Perplexity: 10.2527
# Epoch [3/3], Step [10100/12942], Loss: 2.1749, Perplexity: 8.80098
# Epoch [3/3], Step [10200/12942], Loss: 2.1521, Perplexity: 8.60276
# Epoch [3/3], Step [10300/12942], Loss: 2.0731, Perplexity: 7.94944
# Epoch [3/3], Step [10400/12942], Loss: 2.5624, Perplexity: 12.9668
# Epoch [3/3], Step [10500/12942], Loss: 1.9771, Perplexity: 7.22197
# Epoch [3/3], Step [10600/12942], Loss: 1.8132, Perplexity: 6.13004
# Epoch [3/3], Step [10700/12942], Loss: 2.1661, Perplexity: 8.72432
# Epoch [3/3], Step [10800/12942], Loss: 1.9560, Perplexity: 7.07121
# Epoch [3/3], Step [10900/12942], Loss: 2.6108, Perplexity: 13.6104
# Epoch [3/3], Step [11000/12942], Loss: 2.5014, Perplexity: 12.1993
# Epoch [3/3], Step [11100/12942], Loss: 2.4729, Perplexity: 11.8571
# Epoch [3/3], Step [11200/12942], Loss: 1.9857, Perplexity: 7.28431
# Epoch [3/3], Step [11300/12942], Loss: 2.0172, Perplexity: 7.51767
# Epoch [3/3], Step [11400/12942], Loss: 2.4503, Perplexity: 11.5921
# Epoch [3/3], Step [11500/12942], Loss: 1.9026, Perplexity: 6.70337
# Epoch [3/3], Step [11600/12942], Loss: 2.0171, Perplexity: 7.51661
# Epoch [3/3], Step [11700/12942], Loss: 2.1811, Perplexity: 8.85644
# Epoch [3/3], Step [11800/12942], Loss: 1.9764, Perplexity: 7.21676
# Epoch [3/3], Step [11900/12942], Loss: 2.6330, Perplexity: 13.9159
# Epoch [3/3], Step [12000/12942], Loss: 1.9700, Perplexity: 7.17080
# Epoch [3/3], Step [12100/12942], Loss: 1.9195, Perplexity: 6.81768
# Epoch [3/3], Step [12200/12942], Loss: 2.2180, Perplexity: 9.18923
# Epoch [3/3], Step [12300/12942], Loss: 2.2743, Perplexity: 9.72109
# Epoch [3/3], Step [12400/12942], Loss: 2.0856, Perplexity: 8.04985
# Epoch [3/3], Step [12500/12942], Loss: 2.0485, Perplexity: 7.75616
# Epoch [3/3], Step [12600/12942], Loss: 2.0270, Perplexity: 7.59133
# Epoch [3/3], Step [12700/12942], Loss: 2.1208, Perplexity: 8.33758
# Epoch [3/3], Step [12800/12942], Loss: 1.9493, Perplexity: 7.02392
# Epoch [3/3], Step [12900/12942], Loss: 2.0192, Perplexity: 7.53257
# Epoch [3/3], Step [12942/12942], Loss: 2.1977, Perplexity: 9.00453

# %% [markdown]
# <a id='step3'></a>
# ## Step 3: (Optional) Validate your Model
#
# To assess potential overfitting, one approach is to assess performance on a validation set.  If you decide to do this **optional** task, you are required to first complete all of the steps in the next notebook in the sequence (**3_Inference.ipynb**); as part of that notebook, you will write and test code (specifically, the `sample` method in the `DecoderRNN` class) that uses your RNN decoder to generate captions.  That code will prove incredibly useful here.
#
# If you decide to validate your model, please do not edit the data loader in **data_loader.py**.  Instead, create a new file named **data_loader_val.py** containing the code for obtaining the data loader for the validation data.  You can access:
# - the validation images at filepath `'/opt/cocoapi/images/train2014/'`, and
# - the validation image caption annotation file at filepath `'/opt/cocoapi/annotations/captions_val2014.json'`.
#
# The suggested approach to validating your model involves creating a json file such as [this one](https://github.com/cocodataset/cocoapi/blob/master/results/captions_val2014_fakecap_results.json) containing your model's predicted captions for the validation images.  Then, you can write your own script or use one that you [find online](https://github.com/tylin/coco-caption) to calculate the BLEU score of your model.  You can read more about the BLEU score, along with other evaluation metrics (such as TEOR and Cider) in section 4.1 of [this paper](https://arxiv.org/pdf/1411.4555.pdf).  For more information about how to use the annotation file, check out the [website](http://cocodataset.org/#download) for the COCO dataset.

# %%
# (Optional) TODO: Validate your model.
with torch.no_grad():
    model.eval()
